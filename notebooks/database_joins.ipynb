# %%
# !pip install shapely
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import FileLink

# %%
division_level_recommendations = pd.read_csv('../data/division_level_recommendations.csv')

# %%
division_level_recommendations
# Out:
#       PRIMARY_STOCKNO  shoe_rec1   shoe_rec2   shoe_rec3  shoe_pctsaleswith1  \
# 0            99497860  1497860.0  99497858.0  99498066.0            8.383234
# 1              497403   498066.0    497419.0    398564.0           10.071014
# 2             1497835  1497800.0   1497878.0   1497721.0            2.987698
# 3              398564   398913.0    398566.0   1398564.0           11.056342
# 4             1399645  1398564.0   1398566.0   1398329.0            5.464481
# ...               ...        ...         ...         ...                 ...
# 2879         99521194       -1.0        -1.0        -1.0                 NaN
# 2880           399921       -1.0        -1.0        -1.0                 NaN
# 2881          1480927       -1.0        -1.0        -1.0                 NaN
# 2882          1479840       -1.0        -1.0        -1.0                 NaN
# 2883          1480969       -1.0        -1.0        -1.0                 NaN
#
# ...

# %%
division_level_recommendations = division_level_recommendations[~(division_level_recommendations[['shoe_rec1', 'shoe_rec2', 'shoe_rec3']] == -1).all(axis=1)]
division_level_recommendations
# Out:
#       PRIMARY_STOCKNO   shoe_rec1   shoe_rec2   shoe_rec3  shoe_pctsaleswith1  \
# 0            99497860   1497860.0  99497858.0  99498066.0            8.383234
# 1              497403    498066.0    497419.0    398564.0           10.071014
# 2             1497835   1497800.0   1497878.0   1497721.0            2.987698
# 3              398564    398913.0    398566.0   1398564.0           11.056342
# 4             1399645   1398564.0   1398566.0   1398329.0            5.464481
# ...               ...         ...         ...         ...                 ...
# 2839          1794491  99794491.0   1794489.0   1794478.0            6.250000
# 2840         99794491   1794491.0  99794472.0  99794486.0            6.349206
# 2842         99389055   1389055.0  99497878.0  99398711.0            4.123711
# 2844         99389051   1389051.0  99401805.0  99398711.0            8.641975
# 2850         99401719  99437036.0   1401765.0  99436599.0            7.368421
#
# ...

# %%
division_level_recommendations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1655 entries, 0 to 2850
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PRIMARY_STOCKNO       1655 non-null   int64
#  1   shoe_rec1             1655 non-null   float64
#  2   shoe_rec2             1655 non-null   float64
#  3   shoe_rec3             1655 non-null   float64
#  4   shoe_pctsaleswith1    1647 non-null   float64
#  5   shoe_pctsaleswith2    1617 non-null   float64
#  6   shoe_pctsaleswith3    1453 non-null   float64
#  7   shoe_rec1_count       1655 non-null   float64
#  8   shoe_rec2_count       1655 non-null   float64
#  9   shoe_rec3_count       1655 non-null   float64
#  10  shoe_rec_level        1655 non-null   object
#  11  access_rec1           1654 non-null   float64
#  12  access_rec2           1654 non-null   float64
#  13  access_rec3           1654 non-null   float64
# ...

# %%
division_level_recommendations['shoe_rec1'] = division_level_recommendations['shoe_rec1'].astype(int)
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_27856\2232921486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   division_level_recommendations['shoe_rec1'] = division_level_recommendations['shoe_rec1'].astype(int)

# %%
division_level_recommendations['shoe_rec2'] = division_level_recommendations['shoe_rec2'].astype(int)
# Out:
# C:\Users\houxu\AppData\Local\Temp\ipykernel_27856\2336028012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   division_level_recommendations['shoe_rec2'] = division_level_recommendations['shoe_rec2'].astype(int)

# %%
division_level_recommendations['shoe_rec3'] = division_level_recommendations['shoe_rec3'].astype(int)
division_level_recommendations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2884 entries, 0 to 2883
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PRIMARY_STOCKNO       2884 non-null   int64
#  1   shoe_rec1             2884 non-null   int32
#  2   shoe_rec2             2884 non-null   int32
#  3   shoe_rec3             2884 non-null   int32
#  4   shoe_pctsaleswith1    1647 non-null   float64
#  5   shoe_pctsaleswith2    1617 non-null   float64
#  6   shoe_pctsaleswith3    1453 non-null   float64
#  7   shoe_rec1_count       2884 non-null   float64
#  8   shoe_rec2_count       2884 non-null   float64
#  9   shoe_rec3_count       2884 non-null   float64
#  10  shoe_rec_level        2884 non-null   object
#  11  access_rec1           2577 non-null   float64
#  12  access_rec2           2577 non-null   float64
#  13  access_rec3           2577 non-null   float64
# ...

# %% [markdown]
# #### we cannot convert the accessories recommendations or counts to ints, pulls error

# %%
shoe_recs = pd.read_csv('../data/shoerecs.csv')
shoe_recs
# Out:
#         district  primary_stockno     shoe1    level1       pct1     shoe2  \
# 0             15           399773    398913  district  10.465116    399772
# 1             15           480990    481000     state   8.256881    481008
# 2             15           398572    399772  district  15.384615    398562
# 3             15           398274    398572  district  14.814815    398562
# 4             15          1581707   1581705       div   6.144465   1581706
# ...          ...              ...       ...       ...        ...       ...
# 112473        36          1794491   1794489       div   6.250000  99794491
# 112474        36         99794491  99794472       div   6.349206   1794491
# 112475        36         99389051   1389051       div   8.641975  99401805
# 112476        36         99401719  99437036       div   7.368421   1401765
# 112477        36           382061    382105       div  30.434783    382041
#
#           level2       pct2     shoe3    level3       pct3
# ...

# %%
all_shoes_images = pd.read_csv('../data/all_shoes_images.csv')
all_shoes_images.head(3)
# Out:
#    Unnamed: 0                                       shoe_name  stock_number  \
# 0           0             Crocs Classic Glitzy Clog - Vanilla        521261
# 1           1            Crocs Classic Glitzy Clog - Flamingo        521262
# 2           2  Vans Knu Skool Skate Shoe - Black / True White        497973
#
#                                                image  STOCKNO_x  \
# 0  https://images.journeys.com/images/products/1_...     521261
# 1  https://images.journeys.com/images/products/1_...     521262
# 2  https://images.journeys.com/images/products/1_...     497973
#
#            STYLE_DESCR_x  STOCKNO_y          STYLE_DESCR_y
# 0   *CLSC GLITZY VANILLA     521261   *CLSC GLITZY VANILLA
# 1   *CLSC GLITZY LT PINK     521262   *CLSC GLITZY LT PINK
# 2  KNU SKOOL BLACK/WHITE     497973  KNU SKOOL BLACK/WHITE

# %%
all_shoes_images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2981 entries, 0 to 2980
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2981 non-null   int64
#  1   shoe_name      2981 non-null   object
#  2   stock_number   2981 non-null   int64
#  3   image          2981 non-null   object
#  4   STOCKNO_x      2981 non-null   int64
#  5   STYLE_DESCR_x  2981 non-null   object
#  6   STOCKNO_y      2981 non-null   int64
#  7   STYLE_DESCR_y  2981 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 186.4+ KB

# %%
shoe_image_sub = all_shoes_images[['shoe_name', 'stock_number', 
                                'image']]
shoe_image_sub.head(3)
# Out:
#                                         shoe_name  stock_number  \
# 0             Crocs Classic Glitzy Clog - Vanilla        521261
# 1            Crocs Classic Glitzy Clog - Flamingo        521262
# 2  Vans Knu Skool Skate Shoe - Black / True White        497973
#
#                                                image
# 0  https://images.journeys.com/images/products/1_...
# 1  https://images.journeys.com/images/products/1_...
# 2  https://images.journeys.com/images/products/1_...

# %%
accessories_images = pd.read_csv('../data/products_accessories_images.csv')
accessories_images
# Out:
#      Unnamed: 0                                        accessories  \
# 0             0  Crocs Jibbitz&trade; Hello Kitty&reg; Shoe Cha...
# 1             1  Crocs Jibbitz&trade; Outer Space Shoe Charms 5...
# 2             2  Crocs Jibbitz&trade; Teen Bro Shoe Charms 5 Pa...
# 3             3  Crocs Jibbitz&trade; Super Mario Bros. Shoe Ch...
# 4             4  Crocs Jibbitz&trade; Retro Vibe Shoe Charms 5 ...
# ..          ...                                                ...
# 573         851  Main view of Hunter x Hunter Group Photo Tee -...
# 574         855        Main view of Naruto Long Sleeve Tee - Black
# 575         859  Main view of My Hero Academia Lounge Pants - B...
# 576         861                  Main view of Inyuasha Tee - Black
# 577         862  Main view of Bleach Ichigo And Toshiro Tee - W...
#
#      stock_number                                              image
# 0           99470  https://images.journeys.com/images/products/1_...
# ...

# %%
accessories_images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    578 non-null    int64
#  1   accessories   578 non-null    object
#  2   stock_number  578 non-null    int64
#  3   image         578 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 18.2+ KB

# %%
accessory_image_sub = accessories_images[['stock_number', 
                                'image']]
accessory_image_sub
# Out:
#      stock_number                                              image
# 0           99470  https://images.journeys.com/images/products/1_...
# 1            8179  https://images.journeys.com/images/products/1_...
# 2            9406  https://images.journeys.com/images/products/1_...
# 3            9402  https://images.journeys.com/images/products/1_...
# 4           99503  https://images.journeys.com/images/products/1_...
# ..            ...                                                ...
# 573         19142  https://images.journeys.com/images/products/1_...
# 574         48011  https://images.journeys.com/images/products/1_...
# 575         19042  https://images.journeys.com/images/products/1_...
# 576         12266  https://images.journeys.com/images/products/1_...
# 577         50483  https://images.journeys.com/images/products/1_...
#
# [578 rows x 2 columns]

# %% [markdown]
# division_level_recommendations_cleaned = division_level_recommendations.to_csv('../data/division_level_recommendations_cleaned.csv', index = False)
